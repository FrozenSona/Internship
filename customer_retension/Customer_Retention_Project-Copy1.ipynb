# %% [markdown]
# ## E-retail factors for customer activation and retention:
# ### A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention.
#
# #### Five major factors that contributed to the success of an e-commerce store have been identified as:
# - service quality
# - system quality
# - information quality
# - trust
# - net benefit.
#
# The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %% [markdown]
# #### Importing the required libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Loading the dataset:

# %%
df = pd.read_excel('customer_retention_dataset.xlsx', 'datasheet')

df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
# Checking for the column names:

df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# #### Hedonic Values:

# %%
print('Hedonic values of the dataset are: \n','='*80,'\n',df.columns[:47])
# Out:
# Hedonic values of the dataset are:
# ...
#  Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
# ...

# %% [markdown]
# #### Utilitarain Values:

# %%
print('Utilitarain Values of the dataset are: \n','='*80,'\n',df.columns[47:])
# Out:
# Utilitarain Values of the dataset are:
# ...
#  Index(['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
#        'Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options', 'Speedy order delivery ',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
# ...

# %% [markdown]
# #### Renaming the column names:

# %%
df = df.rename(columns={'1Gender of respondent':'Gender', '2 How old are you? ':'Age', '3 Which city do you shop online from?':'city',
               '4 What is the Pin Code of where you shop online from?':'pin_code', '5 Since How Long You are Shopping Online ?':'shopping_year',
              '6 How many times you have made an online purchase in the past 1 year?':'1year_purchase',
              '7 How do you access the internet while shopping on-line?':'Internet_type',
              '8 Which device do you use to access the online shopping?':'device_type',
              '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'mobile_screen_size',
              '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'Operating_system',
              '11 What browser do you run on your device to access the website?\t\t\t                                                          ':'browser',
              '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'channel_type',
              '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'first_visit',
              '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'time_spend',
              '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'payment_option',
            '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'abandon_cart',
             '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'abandon_reason',
             '18 The content on the website must be easy to read and understand':'content_feasibility',
              '19 Information on similar product to the one highlighted  is important for product comparison':'similar_product',
              '20 Complete information on listed seller and product being offered is important for purchase decision.':'seller_information',
              '21 All relevant information on listed products must be stated clearly':'product_information',
              '22 Ease of navigation in website':'navigation_ease', '23 Loading and processing speed':'speed',
              '24 User friendly Interface of the website':'website_interface','25 Convenient Payment methods':'payment_methods',
             '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'trust',
             '27 Empathy (readiness to assist with queries) towards the customers':'empathy',
              '28 Being able to guarantee the privacy of the customer':'privacy_guarantee',
             '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Responsiveness',
              '30 Online shopping gives monetary benefit and discounts':'online_benefit','31 Enjoyment is derived from shopping online':'enjoyment',
              '32 Shopping online is convenient and flexible':'convenient', '33 Return and replacement policy of the e-tailer is important for purchase decision':'replacement',
             '34 Gaining access to loyalty programs is a benefit of shopping online':'loyalty_programs', '35 Displaying quality Information on the website improves satisfaction of customers':'quality_information',
              '36 User derive satisfaction while shopping on a good quality website or application':'website_quality',
              '37 Net Benefit derived from shopping online can lead to users satisfaction':'shopping_benefit',
              '38 User satisfaction cannot exist without trust':'satisfaction_result', '39 Offering a wide variety of listed product in several category':'product_variety',
              '40 Provision of complete and relevant product information':'relevant_info','41 Monetary savings':'savings',
              '42 The Convenience of patronizing the online retailer':'convenience',
              '43 Shopping on the website gives you the sense of adventure':'adventure', '44 Shopping on your preferred e-tailer enhances your social status':'social_status',
              '45 You feel gratification shopping on your favorite e-tailer':'gratification', '46 Shopping on the website helps you fulfill certain roles':'roles',
              '47 Getting value for money spent':'value_for_money', 
              'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'retailers',
              'Easy to use website or application':'use_ease', 'Visual appealing web-page layout':'layout', 'Wild variety of product on offer':'product_on_offer',
              'Complete, relevant description information of products':'product_description', 'Fast loading website speed of website and application':'loading_speed',
              'Reliability of the website or application':'website_reliability', 'Quickness to complete purchase':'quick_purchase',
              'Availability of several payment options':'payment_availability', 'Speedy order delivery ':'delivery_speed','Privacy of customers’ information':'customer_privacy',
              'Security of customer financial information':'financial_security', 'Perceived Trustworthiness':'Trustworthiness',
              'Presence of online assistance through multi-channel':'assistance_presence',
              'Longer time to get logged in (promotion, sales period)':'promotion_period', 'Longer time in displaying graphics and photos (promotion, sales period)':'graphics_time',
              'Late declaration of price (promotion, sales period)':'price_declaration', 'Longer page loading time (promotion, sales period)':'page_loading_time',
              'Limited mode of payment on most products (promotion, sales period)':'limited_payment_mode',
              'Longer delivery period':'delivery_period', 'Change in website/Application design':'design_change', 
              'Frequent disruption when moving from one page to another':'disruption_page', 'Website is as efficient as before':'efficient_website',
       'Which of the Indian online retailer would you recommend to a friend?':'recommandations'})

# %%
#Checking for the dataset after renaming the columns

df.head()
# Out:
#    Gender          Age           city  pin_code  shopping_year  \
# 0    Male  31-40 years          Delhi    110009  Above 4 years
# 1  Female  21-30 years          Delhi    110030  Above 4 years
# 2  Female  21-30 years  Greater Noida    201308      3-4 years
# 3    Male  21-30 years        Karnal     132001      3-4 years
# 4  Female  21-30 years     Bangalore     530068      2-3 years
#
#        1year_purchase    Internet_type device_type mobile_screen_size  \
# 0         31-40 times          Dial-up     Desktop             Others
# 1  41 times and above            Wi-Fi  Smartphone         4.7 inches
# 2  41 times and above  Mobile Internet  Smartphone         5.5 inches
# 3  Less than 10 times  Mobile Internet  Smartphone         5.5 inches
# 4         11-20 times            Wi-Fi  Smartphone         4.7 inches
#
#         Operating_system  ...         promotion_period  \
# 0  Window/windows Mobile  ...                Amazon.in
# ...

# %%
# Checking for the shape of the dataset

df.shape
# Out:
# (269, 71)

# %% [markdown]
# - There are 269 rows and 71 columns in the dataset.

# %%
# To display maximum data

pd.set_option('display.max_rows', None)

# %%
# Checking for the missing values in the dataset:

df.isnull().sum()
# Out:
# Gender                  0
# Age                     0
# city                    0
# pin_code                0
# shopping_year           0
# 1year_purchase          0
# Internet_type           0
# device_type             0
# mobile_screen_size      0
# Operating_system        0
# browser                 0
# channel_type            0
# first_visit             0
# time_spend              0
# payment_option          0
# abandon_cart            0
# abandon_reason          0
# content_feasibility     0
# similar_product         0
# seller_information      0
# product_information     0
# navigation_ease         0
# speed                   0
# website_interface       0
# payment_methods         0
# trust                   0
# empathy                 0
# privacy_guarantee       0
# Responsiveness          0
# online_benefit          0
# enjoyment               0
# convenient              0
# replacement             0
# loyalty_programs        0
# quality_information     0
# ...

# %% [markdown]
# - From the above observation, we can say that there is no missing values in the dataset.

# %%
# Checking for the datatype of the dataset

df.dtypes
# Out:
# Gender                  object
# Age                     object
# city                    object
# pin_code                 int64
# shopping_year           object
# 1year_purchase          object
# Internet_type           object
# device_type             object
# mobile_screen_size      object
# Operating_system        object
# browser                 object
# channel_type            object
# first_visit             object
# time_spend              object
# payment_option          object
# abandon_cart            object
# abandon_reason          object
# content_feasibility     object
# similar_product         object
# seller_information      object
# product_information     object
# navigation_ease         object
# speed                   object
# website_interface       object
# payment_methods         object
# trust                   object
# empathy                 object
# privacy_guarantee       object
# Responsiveness          object
# online_benefit          object
# ...

# %% [markdown]
# - The dataset contains object and integer datatype.

# %%
# Checking for the information of the dataset:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                269 non-null    object
#  1   Age                   269 non-null    object
#  2   city                  269 non-null    object
#  3   pin_code              269 non-null    int64
#  4   shopping_year         269 non-null    object
#  5   1year_purchase        269 non-null    object
#  6   Internet_type         269 non-null    object
#  7   device_type           269 non-null    object
#  8   mobile_screen_size    269 non-null    object
#  9   Operating_system      269 non-null    object
#  10  browser               269 non-null    object
#  11  channel_type          269 non-null    object
#  12  first_visit           269 non-null    object
#  13  time_spend            269 non-null    object
#  14  payment_option        269 non-null    object
# ...

# %% [markdown]
# - Observations:
#     - The dataset contains 269 rows and 71 columns as said earlier.
#     - No missing values in the dataset as said earlier.
#     - 70 columns contain object datatype.
#     - 1 column contains integer datatype.

# %% [markdown]
# #### Data Visualization:

# %% [markdown]
# ###### 1. Gender

# %%
# Checking the value counts of Gender column

df['Gender'].value_counts()
# Out:
# Female    181
# Male       88
# Name: Gender, dtype: int64

# %%
# Plotting pie plot to show the distribution of gender column

plt.figure(figsize=[6,6])
df['Gender'].value_counts().plot.pie(autopct = '%.1f%%')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# - The number of female customers is more than male customers
# - We can say that females are more intrested in online shopping than males.

# %%
# Plotting bar graph to show the relationship between Gender and Gratification

plt.figure(figsize=[8,6])
sns.set_style(style='whitegrid')
sns.countplot(x=df['Gender'], hue=df['gratification'], data =df)
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.title('Gender gratification feeling')
plt.show()

# %% [markdown]
# - From the graph, we can say that females customers are more engaged in online shopping as compared to male customers.
#
# - Analysis for Male customers:
#     - Most of the male customers agrees that they feel gratification shopping on their favorite e-tailer.
#     - Very few male customers strongly disagree.
#
# - Analysis for the female customers:
#     - Most female customers feel indifferent while shopping online.
#     - Approx 10 female customers strongly disagree and disagree while shopping online.

# %%
# Plotting graph to show the distribution if the customers feel shopping on the website helps them fulfill certain roles. (Gender wise)

plt.figure(figsize=[10,6])
sns.countplot(x=df['Gender'], hue=df['roles'], data=df)
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.title('Distribution of Roles gender wise')
plt.show()

# %% [markdown]
# - Analysis for the male customers:
#     - Maximum male customers agree that shopping on the website helps them fulfill certain roles.
#     - Very few (negligiable) male disagree with this.
#
# - Analysis for the female customers:
#     - Most of the female customers feel indifferent while shopping online.

# %%
# Plotting graph to show gender wise distribution who feels shopping online enhances their social status.

plt.figure(figsize=[10,6])
sns.countplot(x=df['Gender'], hue=df['social_status'], data=df)
plt.ylabel('Counts')
plt.xlabel('Gender')
plt.title('Gender Vs Social Status')
plt.show()

# %% [markdown]
# - The distribution graph shows that most of the customers(Males and females) feel indifferent whether shopping online enchances the social status.
# - Majority of the customers feels shopping online enhances the social status.

# %%
# Plotting graph to show the customers view on shopping on the website gives them the sense of adventure

plt.figure(figsize=[10,6])
sns.countplot(x=df['Gender'], hue=df['adventure'], data =df)
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.title('Sense of Adventure while shopping online')
plt.show()

# %% [markdown]
# - maximum of the customers (Male+Female) agrees that shopping on the website gives them the sense of adventure.
# - In tha case of Male customers the percentage is more whom feels shopping on the website gives them the sense of adventure.
# - In the case of Female customers the percentage is less.

# %% [markdown]
# ###### 2. Age

# %%
# Checking for the value counts of the Age column.

df['Age'].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64

# %% [markdown]
# - We've 5 categories:
#     - Less than 20 years.
#     - 21-30 years.
#     - 31-40 years.
#     - 41-50 years.
#     - 51 years and above.

# %%
# Plotting pie plot to show the distribution of column 'Age'
plt.figure(figsize=[6,6])
df['Age'].value_counts().plot.pie(autopct= '%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# Observations:
#
# - The persons whose age lies between 21 to 50 have maximum chance that they will prefer online shopping. We can say this is because of the persons in the age group 21 to 50 are more tech svvy.
#
# - Persons above the age of 50 years have minimum chance of shopping online becuase they are not so much tech svvy.
#
# - Persons below the age of 20 years have also minimum chance of shopping online as may be they don't have credit or debit cards.

# %%
# Showing the distribution of age group on graph who feel gratification in shopping online

plt.figure(figsize=[12,8])
sns.countplot(df['Age'], hue=df['gratification'], data=df)
plt.xlabel('Age Group')
plt.ylabel('Counts')
plt.title('Age Distribution Vs Gratification')
plt.show()

# %% [markdown]
# - For the age group of 21 to 40 years most of the persons are indiffernet that shopping online gives them feeling of gratification or not.
#
# - Most of the persons of age group 41 to 50 years feel gratification if they shop online.
#
# - Foe the age below 20 years and above 50 years most of the persons are indifferent.

# %%
# Showing the distribution of age group on graph who feels shopping online fulfills certain role in their life.

plt.figure(figsize=[12,8])
sns.countplot(df['Age'], hue=df['roles'], data=df)
plt.xlabel('Age Group')
plt.ylabel('Counts')
plt.title('Age Distribution Vs Roles')
plt.show()

# %% [markdown]
# - For the age group of 31 to 40 and 41 to 50 years most of the customers agrees that shopping online helps them fulfill certain roles.
#
# - For the age group of 21 to 30 years most of the customers are indifferent that shopping online helps them fullfill certain roles.
#
# -  Customers below the age of 20 years also agrees that shopping online helps them fulfill certain roles.
#
# - Customers above the age of 50 years disagree with this.

# %%
# Showing the distribution of age group on graph who feels shopping online enchances socail status.

plt.figure(figsize=[12,8])
sns.countplot(df['Age'], hue=df['social_status'], data=df)
plt.xlabel('Age Group')
plt.ylabel('Counts')
plt.title('Age Distribution Vs Social Status')
plt.show()

# %% [markdown]
# - Most customers of the age group 31 to 40 years, 41 to 50 years, below 20 years and above 51 years are indifferent that shopping online enhances social status.
#
# - Most customers of the age group 21 to 30 years agrees that shopping online enhances social status.

# %%
# Showing the distribution of age group on graph who feels shopping online gives them sense of adventure.

plt.figure(figsize=[12,8])
sns.countplot(df['Age'], hue=df['adventure'], data=df)
plt.xlabel('Age Group')
plt.ylabel('Counts')
plt.title('Age Distribution Vs Adventure')
plt.show()

# %% [markdown]
# Observations:
#
# - For the age group 21 to 40 most of the customers agrees that shopping online gives them sense of adventure.
# - Customers below the age of 20 also feels shooping online gives sense of adventure.
# - Customers from the age group 41 to 50 years most of them think they are strongly agree that shopping online give sense of adventure.
# - Customers above the age of 51 years strongly disagree that shopping online give sense of adventure.

# %% [markdown]
# ###### 3. City

# %%
# Checking for the value counts of the coulmn city

df['city'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: city, dtype: int64

# %% [markdown]
# - In the dataset we have the data for the cities Delhi, Greater Noida, Noida, Bangalore, Karnal, Ghaziabad, Solan, Gurgaon, Merrut, Moradabad and Bulandshahr.

# %%
# Plotting pie graph to show the distribution of city column

plt.figure(figsize=[10,10])
df['city'].value_counts().plot.pie(autopct = '%0.1f%%')
# Out:
# <AxesSubplot:ylabel='city'>

# %% [markdown]
# Oservations:
#
# - Customers from Delhi having the maximum chance of online shopping.
# - From the graph we can say that, Tier 1 cities (Delhi, Bangalore) have more chance of online shopping followed by Tier 2 and Tier 3 cities having the low chance of online shopping.

# %%
# Showing the city wise Age distribution using a bar graph.

city_age = pd.crosstab(df.city, df.Age, normalize='index')
city_age.plot.bar(stacked=True, figsize=[12,6])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# Observations:
#
# - More than 50% customers of the city Bangalore, Karnal, and Merrut who prefer to shop online lies in the age group 21 to 30 years.
#
# - For the cities Bulandshahr and Moradabad most of the customers are from the age group of 31 to 40 years(These cities contribute least to the dataset).
#
# - For the city Gurgaon, 51 years and above ccustomers are more active, followed by 31 to 40 years.
#
# - For the city Solan most of the customers are less than 20 years old, followed by 21 to 40 years.
#
# - For the city Delhi, most of the customers are from the age group 41 to 50 years, followed by 31 to 40 years, and 21 to 30 years.
#
# - For the city Ghaziabad, most of the customers are from the age group 31 to 40 years, followed by 41 to 50 years, less than 20 years and 21 to 30 years.
#
# - For the cities Greater Noida and Noida, most of the customers are of age group 31to 40 years.

# %% [markdown]
# ###### 4. Pin_code

# %%
# Checking for the value counts

df['pin_code'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173212     9
# 250001     9
# 173229     9
# 560037     8
# 132036     8
# 560010     8
# 122018     8
# 110011     7
# 201306     7
# 110008     7
# 110014     6
# 110018     6
# 244001     5
# 201312     5
# 530068     5
# 201305     5
# 201009     5
# 201008     5
# 201005     4
# 201001     4
# 201304     4
# 110039     4
# 110030     4
# 110009     4
# 560018     4
# 560003     4
# 122009     4
# 560002     4
# 110042     4
# 201303     4
# 560013     3
# 203001     2
# 560001     1
# 203207     1
# 203202     1
# Name: pin_code, dtype: int64

# %%
# Showing the distribution of pin_code coulmn using graph

plt.figure(figsize=[28,8])
sns.countplot(df['pin_code'], data=df)
plt.xlabel('Pin Codes')
plt.ylabel('Counts')
plt.title('Pin code Distribution')
plt.show()

# %% [markdown]
# - From pincode "201308" (the pincode belongs to Noida city) maximum cutomers shop online.
# - From pincode '132001' (the pincode belongs to Karnal city) is the 2nd highest city from where the customers shop online.
# - From pincode '201310' (the pincode belongs to Greater Noida city) is the 3rd highest city from where customers shops online.
# - Customers from pincode '203202', '203207 (Gautam Buddha Nagar city area), and '560001' (Bangalore city area) shop online very rarely.

# %% [markdown]
# ###### 5. shopping_year

# %%
# Checking for the value counts

df['shopping_year'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: shopping_year, dtype: int64

# %% [markdown]
# - We have total 5 shopping years groups:
#
#     - customers who are shopping online from less than 1 year.
#     - customers who are shopping online from 1 to 2 years.
#     - customers who are shopping online from 2 to 3 years.
#     - customers who are shopping online from 3 to 4 years.
#     - customers who are shopping online from above 4 years.

# %%
# Showing the distribution of shopping_year coumn on the graph

plt.figure(figsize=[8,8])
df['shopping_year'].value_counts().plot.pie(autopct = '%0.1f%%')
# Out:
# <AxesSubplot:ylabel='shopping_year'>

# %% [markdown]
# - Most of the customers are shopping online for more than 4 years, followed by 2 to 3 years, 3 to 4 years, less than 1 years and 1 to 2 years.

# %%
# Showing the city wise Age distribution using a bar graph.

shop_year = pd.crosstab(df.Age, df.Gender, normalize='index')
shop_year.plot.bar(stacked=True, figsize=[12,6])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# - For age group 51 years and above the approx 80% customers are females.
# - For age group 31 to 40 years and less than 20 years approx 60% customers are females.
# - For the age group 21 to 30 approx 75% customers are females.
#
# So, we can say that female customers shops online more than male customers.

# %% [markdown]
# #### Let's check for the type of internet used by the customers to shop online

# %%
df['Internet_type'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: Internet_type, dtype: int64

# %%
# As Mobile internet and Mobile Internet is same. We'll replace 'Mobile  internet' to 'Mobile Internet' to make it single.

df['Internet_type'].replace({'Mobile internet':'Mobile Internet'}, inplace=True)

# %%
# Checking for the value counts 

plt.figure(figsize=[6,6])
df['Internet_type'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Internet_type'>

# %% [markdown]
# - More than 70% customers uses mobile internet to shop online.
# - Appprox 28% customers uses wifi to shop online.
# - Dial-up internet is used by very few customers (only approx 2%).

# %% [markdown]
# #### Age wise distribution of internet type used by the customers

# %%
internet_age = pd.crosstab(df.Age, df.Internet_type, normalize='index')
internet_age.plot.bar(stacked=True, figsize=[8,6])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# - Dial-up internet is used by very few customers who are from age group 31 to 40 years.
# - Customers less than 20 years and more than 51 years uses wifi internet more than mobile internet.
# - All other customers uses mobile internet more than wifi to shop online.
# - Approx 80% of customers from the age group 21 to 30 years and 41 to 50 years uses mobile internet to shop online.

# %% [markdown]
# #### Let's check for the devices used by the customers to shop online

# %%
# Checking for the value count of the devices

df['device_type'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: device_type, dtype: int64

# %% [markdown]
# - The above table shows that most of the customers usees smartphone to shop online.

# %%
# Checking for the age wise device type used to shop online by the customers

device_age = pd.crosstab(df.Age, df.device_type, normalize='index')
device_age.plot.bar(stacked=True, figsize=[8,4])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# ###### Observations:
#
# - Less than 20 years customers uses smartphone to shop online.
# - We can also say that smartphone is common devices which is used by all the age group customers to shop online.
# - By the age group of 21 to 30 years, smartphone is mostly used device to shop online.
# - Tablet and desktop is used by very few customers to shop online.
# - Smartphone and laptop is mostly used to shop online by the customers.

# %%
# Checking for the gender wise device used

device_gender = pd.crosstab(df.device_type, df.Gender, normalize='index')
device_gender.plot.bar(stacked=True, figsize=[8,6])
plt.show()

# %% [markdown]
# - Tablet is only used by the male customers.
# - Desktop is equally used by male and female customers.
# - Female customers generally use smartphone and laptop to shop online.

# %% [markdown]
# #### Checking for the operating system used by the customers.

# %%
# Checking for the value counts of the operating system used by the customers:

plt.figure(figsize=[6,6])
df['Operating_system'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Operating_system'>

# %% [markdown]
# - More than 45% customers uses window or window mobile to shop online.
# - Android operating systems are used by approx 32% customers.
# - IOS/Mac operating systems are used by approx 23% customers.

# %% [markdown]
# 1. Age wise distribution of Operating system:

# %%
# Checking for the age wise operating system used by the customers

os_age = pd.crosstab(df.Age, df.Operating_system, normalize='index')
os_age.plot.bar(stacked=True, figsize=[8,6])
plt.show()

# %% [markdown]
# - Customers belonging to age group 21 to 30 years, uses Android, IOS/Mac, and Window/Windows Mobile almost equally.
# - Approx 60% customers belonging to age group 31 to 40 years uses Window/Windows Mobile to shop online.
# - Among the customers who belong to age group less than 20 years, Android operating system is mostly used.

# %%
# Checking for the gender wise operating system used by the customers

os_gender = pd.crosstab(df.Operating_system, df.Gender, normalize='index')
os_gender.plot.bar(stacked=True, figsize=[8,6])
plt.show()

# %% [markdown]
# #### Checking for the browser used by the customers to shop online:

# %%
# Checking for the value counts

plt.figure(figsize=[6,6])
df['browser'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='browser'>

# %% [markdown]
# - Google chrome is commonly used browser among the customers.(approx 80%)
# - Safari is the second most popular browser among the customers.

# %% [markdown]
# #### Checking for the channel followed by the customers to arrive at their favorite online store for the first time

# %%
# Checking for the value counts 

plt.figure(figsize=[6,6])
df['channel_type'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='channel_type'>

# %% [markdown]
# - more than 85% customers uses search engine to arrive at their favourite online store to shop online.

# %% [markdown]
# #### Let's check for the time spend by the customers before making any purchase:

# %%
# Checking for the value counts:

df['time_spend'].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: time_spend, dtype: int64

# %% [markdown]
# - Maximum customers explore the e-store for more than 15 minutes before making any purchase.

# %%
# Checking for the age wise distribution of time spend by the customers before making the purchase.

time_age = pd.crosstab(df.Age, df.time_spend, normalize='index')
time_age.plot.bar(stacked=True, figsize=[8,6])
plt.show()

# %% [markdown]
# - Customers with the age less than 20 years spend less time to make the purchase from the e-store.
# - 21 to 30 years customers takes maximum time to make the purchase.

# %%
# Checking for the gender wise time taken by the customers to make the purchase:

plt.figure(figsize=[8,6])
sns.countplot(df['Gender'], hue=df['time_spend'], data=df)
plt.xlabel('Time Spend')
plt.ylabel('Counts')
plt.title('Gender wise time taken to complete purchase')
plt.show()

# %% [markdown]
# - Female customers spend more time on e-store to make a purchase than male.

# %% [markdown]
# #### Checking for the preferred payment Options

# %%
# Checking for the count of the payment options

plt.figure(figsize=[6,6])
df['payment_option'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='payment_option'>

# %% [markdown]
# - Maximum customers uses online method to make the payment while shopping online.
# - Credit/Debit card payment option is most popular payment method among the customers to shop online.

# %%
# Checking for the age wise payment method used by the customers

pay_age = pd.crosstab(df.Age, df.payment_option, normalize='index')
pay_age.plot.bar(stacked=True, figsize=[8,6])
plt.show()

# %% [markdown]
# - Most of the customers whose age is less than 20 years use cash on delivery (COD) option to make the payment. This may be because they might not have the access to credit/decit cards.
#
# - 51 years and above customers do not use E-wallets to make payment. This shows that E-wallets are not popular among the age group of 50 years and above.

# %%
# Checking for the payment methods used by different genders

plt.figure(figsize=[8,6])
sns.countplot(x=df['Gender'], hue=df['payment_option'], data=df)
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.title('Payment options used by genders')
plt.show()

# %% [markdown]
# - Credit/Debit cards is the most popular payment option among both the genders.

# %% [markdown]
# #### Let's check how frequently customers abandon shopping cart:

# %%
# Checking for the value counts

plt.figure(figsize=[6,6])
df['abandon_cart'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='abandon_cart'>

# %% [markdown]
# - Approx 64% of customers rarely abandon shopping cart.
# - Approx 18% of customers never abandon shopping cart.

# %%
# Checking for the shopping cart abandon by male and female customers

plt.figure(figsize=[8,6])
sns.countplot(x=df['abandon_cart'], hue=df['Gender'], data=df)
plt.xlabel('Cart Abandon')
plt.ylabel('Counts')
plt.title('Gender wise cart abandon')
plt.show()

# %% [markdown]
# - As compared to male female customers, frequently abandon the shopping cart.

# %% [markdown]
# #### Let's check why customers abandon shopping cart:

# %%
# Checking for the value counts

plt.figure(figsize=[6,6])
df['abandon_reason'].value_counts().plot.pie(autopct = '%0.1f%%')
# Out:
# <AxesSubplot:ylabel='abandon_reason'>

# %% [markdown]
# - Approx 50% customers abandon shopping cart because they get better alternative offers.
# - Approx 20% customers abandon shopping cart because they were not able to apply the promo code.
# - Approx 11.5% customers abandon shopping cart because of lack of trust.

# %% [markdown]
# #### Let's check if the customers think content on the website must be easy to read and understand

# %%
# Checking for the value counts

plt.figure(figsize=[6,6])
df['content_feasibility'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='content_feasibility'>

# %% [markdown]
# - 61% customers strongly agree that the content on the website must be easy to read and understand.
# - Approx 30% customers agree that the content on the websote must be easy to read and understand.
# - This shows that the content on the website of the e-store must be easy to read and understand as more than 90% customers agree with this.

# %% [markdown]
# #### Let's check how information on the listed seller and product helps customer for purchase decision:

# %%
plt.figure(figsize=[6,6])
df['seller_information'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='seller_information'>

# %% [markdown]
# - As checked approx 32% cutomers strongly agree and approx 38% customers agree that complete information on listed seller and product being offered is important for purchase decision.

# %% [markdown]
# #### All relevant information on listed products must be stated clearly

# %%
plt.figure(figsize=[6,6])
df['product_information'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='product_information'>

# %% [markdown]
# - The above pie graph clearly shows that it is very important to state all the relevant information on listed products very clearly.

# %% [markdown]
# #### Ease of navigation in website

# %%
plt.figure(figsize=[6,6])
df['navigation_ease'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='navigation_ease'>

# %% [markdown]
# - The above graph clearly shows that navigation in website should be easy.

# %% [markdown]
# #### Loading and processing speed:

# %%
plt.figure(figsize=[6,6])
df['speed'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='speed'>

# %% [markdown]
# - The graph clearly shows that the loading and processing speed of the website should be fast.

# %% [markdown]
# #### User friendly Interface of the website

# %%
plt.figure(figsize=[6,6])
df['website_interface'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='website_interface'>

# %% [markdown]
# - The graph clearly shows that the website should have user friendly interface.

# %% [markdown]
# #### Convenient Payment methods:

# %%
plt.figure(figsize=[6,6])
df['payment_methods'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='payment_methods'>

# %% [markdown]
# - The graph clearly shows that convenient payment methods helps in online shopping.

# %% [markdown]
# #### Trust that the online retail store will fulfill its part of the transaction at the stipulated time

# %%
plt.figure(figsize=[6,6])
df['trust'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='trust'>

# %% [markdown]
# - The graph shows that the customers trust that the online retail store will fulfill its part of the transaction at the stipulated time.

# %%
# Checking for the trust city wise

plt.figure(figsize=[12,6])
sns.countplot(x=df['city'], hue=df['trust'], data=df)
plt.xlabel('City Name')
plt.ylabel('Counts')
plt.title('Trust show by the customers city wise')
plt.show()

# %% [markdown]
# - All the customers from the cities Ghaziabad and Moradabad strongly trust that the online retail store will fulfill its part of the transaction at the stipulated time.
#
# - All customers from the city bulandshahr are indifferent that the online retail store will fulfill its part of the transaction at the stipulated time.
#
# - Most of the customers from the cities Delhi, Karnal, bangalore, and Solan trust that the online retail store will fulfill its part of the transaction at the stipulated time.
#
# - Most of the customers from the cities Greater Noida, Noida, Gurgaon strongly trust that the online retail store will fulfill its part of the transaction at the stipulated time.
#
# - Maximum customers from the city Merrut do not trust that the online retail store will fulfill its part of the transaction at the stipulated time.

# %% [markdown]
# #### Being able to guarantee the privacy of the customer:

# %%
plt.figure(figsize=[6,6])
df['privacy_guarantee'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='privacy_guarantee'>

# %% [markdown]
# - Maximum customers agrees that the online retail stores are being able to guarantee the privacy of the customer.

# %% [markdown]
# #### Online shopping gives monetary benefit and discounts

# %%
plt.figure(figsize=[6,6])
df['online_benefit'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='online_benefit'>

# %% [markdown]
# - Most of the customers agrees that online shopping gives them monetary benefit and discounts.

# %% [markdown]
# #### Enjoyment is derived from shopping online

# %%
plt.figure(figsize=[6,6])
df['enjoyment'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='enjoyment'>

# %%
# Checking for the city wise views of the customers regarding enjoyment while shopping online

plt.figure(figsize=[12,6])
sns.countplot(x=df['city'], hue=df['enjoyment'], data=df)
plt.xlabel('City Names')
plt.ylabel('Counts')
plt.title('Enjoyment is derived from shopping online')
# Out:
# Text(0.5, 1.0, 'Enjoyment is derived from shopping online')

# %% [markdown]
# - All the customers from the cities Moradabad and Bulandshahr are indifferent that enjoyment is derived from shopping online.
#
# - Most customers form the cities Karnal and Solan are indifferent that enjoyment is derived from shopping online.
#
# - Most of the customers from the cities Greater Noida, Bangalore, Noida, and Ghaziabad strongly agrees that enjoyment is derived from shopping online.
#
# - Most of the customers from the city Delhi agree that enjoyment is derived from shopping online.
#
# - Most of the customers from the city Meerut are indifferent and strongly disagree that enjoyment is derived from shopping online.

# %% [markdown]
# #### Shopping online is convenient and flexible:

# %%
plt.figure(figsize=[6,6])
df['convenient'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='convenient'>

# %% [markdown]
# - The graph shows that most of the customers strongly agrees that shopping online is convenient and flexible.

# %% [markdown]
# #### Return and replacement policy of the e-retailer is important for purchase decision:

# %%
plt.figure(figsize=[6,6])
df['replacement'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='replacement'>

# %% [markdown]
# - The graph shows that return and replacement policy of the e-tailer is important for purchase decision.

# %% [markdown]
# #### Gaining access to loyalty programs is a benefit of shopping online:

# %%
plt.figure(figsize=[6,6])
df['loyalty_programs'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='loyalty_programs'>

# %% [markdown]
# - Approx 43% customers strongly agrees that gaining access to loyalty programs is a benefit of shopping online.
# - Approx 245 customers agrees that gaining access to loyalty programs is a benefit of shopping online.
# - Only about 4% customers strongly disagress that gaining access to loyalty programs is a benefit of shopping online.
# - Approx 6% customers disagree that gaining access to loyalty programs is a benefit of shopping online.
# - Approx 24% customers are indifferent.

# %% [markdown]
# #### Displaying quality Information on the website improves satisfaction of customers:

# %%
plt.figure(figsize=[6,6])
df['quality_information'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='quality_information'>

# %% [markdown]
# - Approx 50% customers strongly agree that displaying quality Information on the website improves satisfaction of customers.
# - Approx 30% customers agree with this and 20% customers are indifferent.
# - No customers disagree with this.

# %% [markdown]
# #### User satisfaction cannot exist without trust:

# %%
plt.figure(figsize=[6,6])
df['satisfaction_result'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='satisfaction_result'>

# %% [markdown]
# - Approx 45% customers strongly agree that user satisfaction cannot exist without trust.
# - Approx 44% cutomers agree that user satisfaction cannot exist without trust.
#
# Hence, we can say that user satisfaction cannot exist without trust.

# %% [markdown]
# #### Shopping on your preferred e-tailer enhances your social status:

# %%
plt.figure(figsize=[6,6])
df['social_status'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='social_status'>

# %% [markdown]
# - Most of the customers are indifferent that shopping online enhances social status.

# %% [markdown]
# #### You feel gratification shopping on your favorite e-tailer:

# %%
plt.figure(figsize=[6,6])
df['gratification'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='gratification'>

# %% [markdown]
# - Most of the users are indifferent that they feel gratification shopping on their favorite e-tailer

# %% [markdown]
# #### Shopping on the website helps you fulfill certain roles:

# %%
plt.figure(figsize=[6,6])
df['roles'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='roles'>

# %% [markdown]
# - Approx 33% customers agree that shopping on the website helps you fulfill certain roles.
# - Approx 14% customers strongly agree that shopping on the website helps you fulfill certain roles.
# - Approx 33% customers are indifferent.

# %% [markdown]
# #### Getting value for money spent:

# %%
plt.figure(figsize=[6,6])
df['value_for_money'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='value_for_money'>

# %% [markdown]
# - Approx 55% customers agree that they get value for money spent while shopping online.
# - Approx 31% customers strongly agree that they get value for money spent.
# - Approx 14% customers are indifferent.
# - This clearly shows that most of the customers accept that they get value for the money spend by them on online shopping.

# %% [markdown]
# #### From the following, tick any (or all) of the online retailers you have shopped from;

# %%
plt.figure(figsize=[6,6])
df['retailers'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='retailers'>

# %% [markdown]
# - The above graph shows that most of the customers uses amazon.in to shop online.

# %% [markdown]
# #### Easy to use website or application

# %%
plt.figure(figsize=[6,6])
df['use_ease'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='use_ease'>

# %% [markdown]
# - Almost all customers says that amazon.in website or application is easy to use followed by flipkart.com and paytm.com.

# %% [markdown]
# #### Visual appealing web-page layout:

# %%
plt.figure(figsize=[6,6])
df['layout'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='layout'>

# %% [markdown]
# -As per the graph we can say that most of the customers says that amazon.com and flipkart.com have visual appealing web-page layout.

# %% [markdown]
# #### Complete, relevant description information of products:

# %%
plt.figure(figsize=[6,6])
df['product_description'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='product_description'>

# %% [markdown]
# - Most of the cusotomers says that amazon.in and flipkart.com have complete, relevant description information of products.

# %% [markdown]
# #### Fast loading website speed of website and application:

# %%
plt.figure(figsize=[6,6])
df['loading_speed'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='loading_speed'>

# %% [markdown]
# - Most of the customers says that amazon.in and flipkart.com have fast loading website speed of website and application.

# %% [markdown]
# #### Reliability of the website or application:

# %%
plt.figure(figsize=[6,6])
df['website_reliability'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='website_reliability'>

# %% [markdown]
# - Most of the customers say that amazon.in and flipkart.com have reliability of the website or application.

# %% [markdown]
# #### Quickness to complete purchase:

# %%
plt.figure(figsize=[6,6])
df['quick_purchase'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='quick_purchase'>

# %% [markdown]
# - The graph shows that amazon.in have quickness to complete purchase.

# %% [markdown]
# #### Availability of several payment options:

# %%
plt.figure(figsize=[6,6])
df['payment_availability'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='payment_availability'>

# %% [markdown]
# - Several payment options are available with amazon.in

# %% [markdown]
# #### Privacy of customers’ information:

# %%
plt.figure(figsize=[6,6])
df['customer_privacy'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='customer_privacy'>

# %% [markdown]
# - More than 80% customers thinks their information is safe on amazon.in.

# %% [markdown]
# #### Security of customer financial information:

# %%
plt.figure(figsize=[6,6])
df['financial_security'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='financial_security'>

# %% [markdown]
# - Most of the customers thinks that amazon.in have better security of customer financial information.

# %% [markdown]
# #### Perceived Trustworthiness:

# %%
plt.figure(figsize=[6,6])
df['Trustworthiness'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Trustworthiness'>

# %% [markdown]
# - Most of the customers say amazon.in have perceived trustworthiness.

# %% [markdown]
# #### Late declaration of price (promotion, sales period):

# %%
plt.figure(figsize=[6,6])
df['price_declaration'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='price_declaration'>

# %% [markdown]
# - Late declaration of price is made by myntra.com and paytm.com during the promotion or sales period.

# %% [markdown]
# #### Longer page loading time (promotion, sales period):

# %%
plt.figure(figsize=[6,6])
df['page_loading_time'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='page_loading_time'>

# %% [markdown]
# - Paytm.com and Myntra.com have longer page loading time during the promotion and sales period.

# %% [markdown]
# #### Limited mode of payment on most products (promotion, sales period):

# %%
plt.figure(figsize=[6,6])
df['limited_payment_mode'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='limited_payment_mode'>

# %% [markdown]
# - During the promotion and sales period snapdeal.com and amazon.in have limited mode of payment on most products.

# %% [markdown]
# #### Longer delivery period:

# %%
plt.figure(figsize=[6,6])
df['delivery_period'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='delivery_period'>

# %% [markdown]
# - Myntra.com take minimum delivery period.
# - Paytm.com and snapdeal.com take maximum delivery period. This may be the reason of low popularity of these web-stores among the customers.

# %%
# Let's check for the city wise delivery period.

plt.figure(figsize=[12,6])
sns.countplot(x=df['city'], hue=df['delivery_period'], data=df)
plt.xlabel('Cities')
plt.ylabel('Counts')
plt.title('City wise delivery period')
plt.show()

# %% [markdown]
# - For city Delhi, maximum delivery period is taken by Snapdeal.com followed by Paytm.com.
# - For city Greater Noida, Karnal, and Noida maximum delivery period is taken by Paytm.com followed by Snapdeal.com.
# - For city Bangalore, Maximum delivery period is taken by fipkart.com followed by paytm and snapdeal.
# - For city Solan, maximum delivery period is taken by Amazon.in

# %% [markdown]
# #### Frequent disruption when moving from one page to another:

# %%
plt.figure(figsize=[6,6])
df['disruption_page'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='disruption_page'>

# %% [markdown]
# - customers face disruption when moving from one page to another in amazon.in and myntra.com

# %% [markdown]
# #### Website is as efficient as before:

# %%
plt.figure(figsize=[6,6])
df['efficient_website'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='efficient_website'>

# %% [markdown]
# - Most of the customers say that amazon.in and flipkart.com websites are as efficient as before.

# %% [markdown]
# #### Which of the Indian online retailer would you recommend to a friend?

# %%
plt.figure(figsize=[6,6])
df['recommandations'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='recommandations'>

# %% [markdown]
# - Most of the customers like to recommend amazon.in and flipkart.com to their friend. This shows that most of the customers like to shop from these two web-store.
# - Also the graph shows that Snapdeal.com have only 4.1% recommandations. This shows customers lack of interest in snapdeal.

# %% [markdown]
# #### Conclusion:
#
# - Online retailers company should focus in offering best services to the customers as customer satisfaction is very important for customer retention.

# %% [markdown]
# #### Conveninece:
#
# - The website user interface should be user friendly. As per our analysis there should be complete product description on the website/application of the e-stores.

# %% [markdown]
# #### Privacy & Payment Security:
#
# Companies should focus on providing proper privacy and payment secruities to the customers as it lead to trust of the customers which is very much important.

# %% [markdown]
# #### Loyalty Programs:
#
# One of the best way to attract the customers to shop online is providing them some loyalty programs and rewarding them once they make any purchase or recommend the website/application to any friends.

# %% [markdown]
# #### Website/Application Technicalities:
#
# - Companies should focus on the speed of the website and page navigations. As smooth navigation help users to decide faster to make any purchase.
